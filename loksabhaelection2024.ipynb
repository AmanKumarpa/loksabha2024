# %%
import pandas as pd
import os
import sqlite3
from sqlalchemy import create_engine
import mysql.connector

# %%
create = create_engine("sqlite:/// election.db")

# %%
def ingest_db(file_path, table_name, conn):
    df1 = pd.read_csv(file_path)
    df1.to_sql(table_name, con=conn, if_exists="replace", index=False)
    print("Ingested:", table_name, df1.shape)   # moved inside function & fixed df name

conn = sqlite3.connect("election.db")

file_path = "C:/Users/amanp/Downloads/election commision.csv"
table_name = os.path.splitext(os.path.basename(file_path))[0]  

ingest_db(file_path, table_name, conn)
# Out:
# Ingested: election commision (61725, 12)

# %%
tables= pd.read_sql_query("select name from sqlite_master where type ='table'",conn)
print(tables)
# Out:
#                  name
# 0            election
# 1        final_result
# 2           elections
# 3       final_results
# 4  election commision

# %%
for table in tables["name"]:
    print(pd.read_sql_query(f'SELECT count(*) AS rows FROM "{table}"', conn))
    print(pd.read_sql_query(f'SELECT * FROM "{table}" LIMIT 5', conn))
# Out:
#     rows
# 0  61725
#     State/Ut Name  Parliamentryconstituencies ParliamentryNumber  \
# 0  Andhra Pradesh                           1              Araku
# 1  Andhra Pradesh                           1              Araku
# 2  Andhra Pradesh                           1              Araku
# 3  Andhra Pradesh                           1              Araku
# 4  Andhra Pradesh                           1              Araku
#
#    Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0               1557153                      10    Palakonda
# 1               1557153                      10    Palakonda
# 2               1557153                      10    Palakonda
# 3               1557153                      10    Palakonda
# 4               1557153                      10    Palakonda
#
#    Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                195673                    33327256                  4441
# 1                195673                    33327256                  4441
# 2                195673                    33327256                  4441
# 3                195673                    33327256                  4441
# 4                195673                    33327256                  4441
#
#             Candidate Name   Party  Votes Secured Evm
# 0  APPALANARASA PACHIPENTA  CPI(M)               3873
# 1   AVASHYA LAHARI . VARAM     BSP               1155
# 2        KOTHAPALLI GEETHA     BJP              66695
# 3       GUMMA THANUJA RANI   YSRCP              63302
# 4          CHANTI BADNAINA    JBNP               1977
#    rows
# 0     0
# Empty DataFrame
# Columns: [State_Ut_Name, Parliamentryconstituencies, ParliamentryName, Total_Electors_In_PC, Assemblyconstituencies, AssemblyName, Total_Electors_In_AC, Total_Valid_Votes_In_State, Nota_Votes_Evm_In_AC, Candidate_Name, Party, Votes_Secured_Evm, Total_Votes, Turnout_generalpercent, Votesharepercentage, Votes_pc_party, Winning_Party, Margin]
# Index: []
#     rows
# 0  61725
#     State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0  Andhra Pradesh                           1            Araku
# 1  Andhra Pradesh                           1            Araku
# 2  Andhra Pradesh                           1            Araku
# 3  Andhra Pradesh                           1            Araku
# 4  Andhra Pradesh                           1            Araku
#
#    Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0               1557153                      10    Palakonda
# 1               1557153                      10    Palakonda
# 2               1557153                      10    Palakonda
# 3               1557153                      10    Palakonda
# 4               1557153                      10    Palakonda
#
#    Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                195673                    33327256                  4441
# 1                195673                    33327256                  4441
# 2                195673                    33327256                  4441
# 3                195673                    33327256                  4441
# 4                195673                    33327256                  4441
#
#             Candidate Name   Party  Votes Secured Evm
# 0  APPALANARASA PACHIPENTA  CPI(M)               3873
# 1   AVASHYA LAHARI . VARAM     BSP               1155
# 2        KOTHAPALLI GEETHA     BJP              66695
# 3       GUMMA THANUJA RANI   YSRCP              63302
# 4          CHANTI BADNAINA    JBNP               1977
#     rows
# 0  61725
#   State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0     Rajasthan                          13            AJMER
# 1     Rajasthan                          13            AJMER
# 2     Rajasthan                          13            AJMER
# 3     Rajasthan                          13            AJMER
# 4     Rajasthan                          13            AJMER
#
#    Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0               1999399                      98   KISHANGARH
# 1               1999399                     105        KEKRI
# 2               1999399                     104       MASUDA
# 3               1999399                      99      PUSHKAR
# 4               1999399                     102    NASIRABAD
#
#    Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                286257                    32885413                  1816
# 1                264896                    32885413                  1742
# 2                275740                    32885413                  1436
# 3                254914                    32885413                  1496
# 4                235530                    32885413                  1225
#
#         Candidate Name Party  Votes Secured Evm  Total_Votes  \
# 0  BHAGIRATH CHOUDHARY   BJP             107716      1180237
# 1  BHAGIRATH CHOUDHARY   BJP              98471      1180237
# 2  BHAGIRATH CHOUDHARY   BJP              97421      1180237
# 3  BHAGIRATH CHOUDHARY   BJP              95780      1180237
# 4  BHAGIRATH CHOUDHARY   BJP              89146      1180237
#
#    Turnout generalpercent  Votesharepercentage  Votes_pc_party Winning Party  \
# 0               59.029588             9.126642          741151           BJP
# 1               59.029588             8.343324          741151           BJP
# 2               59.029588             8.254359          741151           BJP
# 3               59.029588             8.115319          741151           BJP
# 4               59.029588             7.553229          741151           BJP
#
#    Margin
# 0    9245
# 1    9245
# 2    9245
# 3    9245
# 4    9245
#     rows
# 0  61725
#     State/Ut Name  Pc No PC Name  Total Electors In PC  AC No    AC Name  \
# 0  Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 1  Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 2  Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 3  Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 4  Andhra Pradesh      1   Araku               1557153     10  Palakonda
#
#    Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                195673                    33327256                  4441
# 1                195673                    33327256                  4441
# 2                195673                    33327256                  4441
# 3                195673                    33327256                  4441
# 4                195673                    33327256                  4441
#
#             Candidate Name   Party  Votes Secured Evm
# 0  APPALANARASA PACHIPENTA  CPI(M)               3873
# 1   AVASHYA LAHARI . VARAM     BSP               1155
# 2        KOTHAPALLI GEETHA     BJP              66695
# 3       GUMMA THANUJA RANI   YSRCP              63302
# 4          CHANTI BADNAINA    JBNP               1977

# %%
ad = pd.read_sql_query('SELECT * FROM "election commision"', conn)
print(ad.head())
# Out:
#     State/Ut Name  Pc No PC Name  Total Electors In PC  AC No    AC Name  \
# 0  Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 1  Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 2  Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 3  Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 4  Andhra Pradesh      1   Araku               1557153     10  Palakonda
#
#    Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                195673                    33327256                  4441
# 1                195673                    33327256                  4441
# 2                195673                    33327256                  4441
# 3                195673                    33327256                  4441
# 4                195673                    33327256                  4441
#
#             Candidate Name   Party  Votes Secured Evm
# 0  APPALANARASA PACHIPENTA  CPI(M)               3873
# 1   AVASHYA LAHARI . VARAM     BSP               1155
# 2        KOTHAPALLI GEETHA     BJP              66695
# 3       GUMMA THANUJA RANI   YSRCP              63302
# 4          CHANTI BADNAINA    JBNP               1977

# %%
ad.columns.tolist()
# Out:
# ['State/Ut Name',
#  'Pc No',
#  'PC Name',
#  'Total Electors In PC',
#  'AC No',
#  'AC Name',
#  'Total Electors In AC',
#  'Total Valid Votes In State',
#  'Nota Votes Evm In AC',
#  'Candidate Name',
#  'Party',
#  'Votes Secured Evm']

# %%
ad["State/Ut Name"]
# Out:
# 0        Andhra Pradesh
# 1        Andhra Pradesh
# 2        Andhra Pradesh
# 3        Andhra Pradesh
# 4        Andhra Pradesh
#               ...
# 61720            Ladakh
# 61721            Ladakh
# 61722            Ladakh
# 61723            Ladakh
# 61724            Ladakh
# Name: State/Ut Name, Length: 61725, dtype: object

# %%
ad
# Out:
#         State/Ut Name  Pc No PC Name  Total Electors In PC  AC No    AC Name  \
# 0      Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 1      Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 2      Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 3      Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 4      Andhra Pradesh      1   Araku               1557153     10  Palakonda
# ...               ...    ...     ...                   ...    ...        ...
# 61720          Ladakh      1  Ladakh                190576      1        Leh
# 61721          Ladakh      1  Ladakh                190576      1        Leh
# 61722          Ladakh      1  Ladakh                190576      2     Kargil
# 61723          Ladakh      1  Ladakh                190576      2     Kargil
# 61724          Ladakh      1  Ladakh                190576      2     Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873
# 1       AVASHYA LAHARI . VARAM     BSP               1155
# 2            KOTHAPALLI GEETHA     BJP              66695
# 3           GUMMA THANUJA RANI   YSRCP              63302
# 4              CHANTI BADNAINA    JBNP               1977
# ...                        ...     ...                ...
# 61720          TSERING NAMGYAL     INC              32014
# 61721           MOHMAD HANEEFA     IND               5733
# 61722            TASHI GYALSON     BJP              10012
# 61723          TSERING NAMGYAL     INC               3756
# 61724           MOHMAD HANEEFA     IND              58710
#
# [61725 rows x 12 columns]

# %%
ad= ad.rename(columns = {"Pc No" : "Parliamentryconstituencies",
                            "AC No" : "Assemblyconstituencies", 
                            "PC Name" : "ParliamentryName",
                           "AC Name" : "AssemblyName"})
ad
# Out:
#         State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0      Andhra Pradesh                           1            Araku
# 1      Andhra Pradesh                           1            Araku
# 2      Andhra Pradesh                           1            Araku
# 3      Andhra Pradesh                           1            Araku
# 4      Andhra Pradesh                           1            Araku
# ...               ...                         ...              ...
# 61720          Ladakh                           1           Ladakh
# 61721          Ladakh                           1           Ladakh
# 61722          Ladakh                           1           Ladakh
# 61723          Ladakh                           1           Ladakh
# 61724          Ladakh                           1           Ladakh
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1557153                      10    Palakonda
# 1                   1557153                      10    Palakonda
# 2                   1557153                      10    Palakonda
# 3                   1557153                      10    Palakonda
# 4                   1557153                      10    Palakonda
# ...                     ...                     ...          ...
# 61720                190576                       1          Leh
# 61721                190576                       1          Leh
# 61722                190576                       2       Kargil
# 61723                190576                       2       Kargil
# 61724                190576                       2       Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873
# 1       AVASHYA LAHARI . VARAM     BSP               1155
# 2            KOTHAPALLI GEETHA     BJP              66695
# 3           GUMMA THANUJA RANI   YSRCP              63302
# 4              CHANTI BADNAINA    JBNP               1977
# ...                        ...     ...                ...
# 61720          TSERING NAMGYAL     INC              32014
# 61721           MOHMAD HANEEFA     IND               5733
# 61722            TASHI GYALSON     BJP              10012
# 61723          TSERING NAMGYAL     INC               3756
# 61724           MOHMAD HANEEFA     IND              58710
#
# [61725 rows x 12 columns]

# %%
ad.columns.tolist()
# Out:
# ['State/Ut Name',
#  'Parliamentryconstituencies',
#  'ParliamentryName',
#  'Total Electors In PC',
#  'Assemblyconstituencies',
#  'AssemblyName',
#  'Total Electors In AC',
#  'Total Valid Votes In State',
#  'Nota Votes Evm In AC',
#  'Candidate Name',
#  'Party',
#  'Votes Secured Evm']

# %%
ad["State/Ut Name"].unique().tolist()
# Out:
# ['Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'West Bengal',
#  'Chhattisgarh',
#  'Jharkhand',
#  'Uttarakhand',
#  'Telangana',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Dadra & Nagar Haveli and Daman & Diu',
#  'NCT OF Delhi',
#  'Lakshadweep',
#  'Puducherry',
#  'Jammu and Kashmir',
#  'Ladakh']

# %%
pd.read_sql_query('select * from "election commision"',conn)
# Out:
#         State/Ut Name  Pc No PC Name  Total Electors In PC  AC No    AC Name  \
# 0      Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 1      Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 2      Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 3      Andhra Pradesh      1   Araku               1557153     10  Palakonda
# 4      Andhra Pradesh      1   Araku               1557153     10  Palakonda
# ...               ...    ...     ...                   ...    ...        ...
# 61720          Ladakh      1  Ladakh                190576      1        Leh
# 61721          Ladakh      1  Ladakh                190576      1        Leh
# 61722          Ladakh      1  Ladakh                190576      2     Kargil
# 61723          Ladakh      1  Ladakh                190576      2     Kargil
# 61724          Ladakh      1  Ladakh                190576      2     Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873
# 1       AVASHYA LAHARI . VARAM     BSP               1155
# 2            KOTHAPALLI GEETHA     BJP              66695
# 3           GUMMA THANUJA RANI   YSRCP              63302
# 4              CHANTI BADNAINA    JBNP               1977
# ...                        ...     ...                ...
# 61720          TSERING NAMGYAL     INC              32014
# 61721           MOHMAD HANEEFA     IND               5733
# 61722            TASHI GYALSON     BJP              10012
# 61723          TSERING NAMGYAL     INC               3756
# 61724           MOHMAD HANEEFA     IND              58710
#
# [61725 rows x 12 columns]

# %%
conn.execute('''alter table "election commision"
                 rename to "elections";''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 conn.execute('''alter table "election commision"
#       2                  rename to "elections";''')
#
# OperationalError: there is already another table or index with this name: elections

# %%
ad1 = pd.read_sql_query(""" select *
                            from elections """, conn)
ad1
# Out:
#         State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0      Andhra Pradesh                           1            Araku
# 1      Andhra Pradesh                           1            Araku
# 2      Andhra Pradesh                           1            Araku
# 3      Andhra Pradesh                           1            Araku
# 4      Andhra Pradesh                           1            Araku
# ...               ...                         ...              ...
# 61720          Ladakh                           1           Ladakh
# 61721          Ladakh                           1           Ladakh
# 61722          Ladakh                           1           Ladakh
# 61723          Ladakh                           1           Ladakh
# 61724          Ladakh                           1           Ladakh
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1557153                      10    Palakonda
# 1                   1557153                      10    Palakonda
# 2                   1557153                      10    Palakonda
# 3                   1557153                      10    Palakonda
# 4                   1557153                      10    Palakonda
# ...                     ...                     ...          ...
# 61720                190576                       1          Leh
# 61721                190576                       1          Leh
# 61722                190576                       2       Kargil
# 61723                190576                       2       Kargil
# 61724                190576                       2       Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873
# 1       AVASHYA LAHARI . VARAM     BSP               1155
# 2            KOTHAPALLI GEETHA     BJP              66695
# 3           GUMMA THANUJA RANI   YSRCP              63302
# 4              CHANTI BADNAINA    JBNP               1977
# ...                        ...     ...                ...
# 61720          TSERING NAMGYAL     INC              32014
# 61721           MOHMAD HANEEFA     IND               5733
# 61722            TASHI GYALSON     BJP              10012
# 61723          TSERING NAMGYAL     INC               3756
# 61724           MOHMAD HANEEFA     IND              58710
#
# [61725 rows x 12 columns]

# %%
ad1 = pd.read_sql_query(""" select distinct ParliamentryName
                            from elections """, conn)
ad1
# Out:
#      ParliamentryName
# 0               Araku
# 1          Srikakulam
# 2        Vizianagaram
# 3       Visakhapatnam
# 4          Anakapalle
# ..                ...
# 535          SRINAGAR
# 536  ANANTNAG-RAJOURI
# 537          UDHAMPUR
# 538             JAMMU
# 539            Ladakh
#
# [540 rows x 1 columns]

# %%
pd.read_sql_query(""" select *
                            from elections 
                            where ParliamentryName = 'Nawada'
                            and AssemblyName in ('Nawada','Hisua') """, conn)
# Out:
#    State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0          Bihar                          39           Nawada
# 1          Bihar                          39           Nawada
# 2          Bihar                          39           Nawada
# 3          Bihar                          39           Nawada
# 4          Bihar                          39           Nawada
# 5          Bihar                          39           Nawada
# 6          Bihar                          39           Nawada
# 7          Bihar                          39           Nawada
# 8          Bihar                          39           Nawada
# 9          Bihar                          39           Nawada
# 10         Bihar                          39           Nawada
# 11         Bihar                          39           Nawada
# 12         Bihar                          39           Nawada
# 13         Bihar                          39           Nawada
# 14         Bihar                          39           Nawada
# 15         Bihar                          39           Nawada
#
#     Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                2010286                     236        Hisua
# 1                2010286                     236        Hisua
# 2                2010286                     236        Hisua
# 3                2010286                     236        Hisua
# 4                2010286                     236        Hisua
# 5                2010286                     236        Hisua
# 6                2010286                     236        Hisua
# 7                2010286                     236        Hisua
# 8                2010286                     237       Nawada
# 9                2010286                     237       Nawada
# 10               2010286                     237       Nawada
# 11               2010286                     237       Nawada
# 12               2010286                     237       Nawada
# 13               2010286                     237       Nawada
# 14               2010286                     237       Nawada
# 15               2010286                     237       Nawada
#
#     Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                 387202                    42549333                  2324
# 1                 387202                    42549333                  2324
# 2                 387202                    42549333                  2324
# 3                 387202                    42549333                  2324
# 4                 387202                    42549333                  2324
# 5                 387202                    42549333                  2324
# 6                 387202                    42549333                  2324
# 7                 387202                    42549333                  2324
# 8                 365188                    42549333                  1661
# 9                 365188                    42549333                  1661
# 10                365188                    42549333                  1661
# 11                365188                    42549333                  1661
# 12                365188                    42549333                  1661
# 13                365188                    42549333                  1661
# 14                365188                    42549333                  1661
# 15                365188                    42549333                  1661
#
#          Candidate Name   Party  Votes Secured Evm
# 0          RANJIT KUMAR     BSP               3135
# 1          VIVEK THAKUR     BJP              82966
# 2         SHRAWAN KUMAR     RJD              63881
# 3     ANAND KUMAR VERMA  BJNJGD               1411
# 4        GANAURI PANDIT    PPID                782
# 5   GAUTAM KUMAR BABLOO  BGDRPP               1140
# 6          GUNJAN KUMAR     IND               5820
# 7           BINOD YADAV     IND               8274
# 8          RANJIT KUMAR     BSP               2218
# 9          VIVEK THAKUR     BJP              69763
# 10        SHRAWAN KUMAR     RJD              67369
# 11    ANAND KUMAR VERMA  BJNJGD               1021
# 12       GANAURI PANDIT    PPID                650
# 13  GAUTAM KUMAR BABLOO  BGDRPP                841
# 14         GUNJAN KUMAR     IND               3271
# 15          BINOD YADAV     IND               9661

# %%
ad
# Out:
#         State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0      Andhra Pradesh                           1            Araku
# 1      Andhra Pradesh                           1            Araku
# 2      Andhra Pradesh                           1            Araku
# 3      Andhra Pradesh                           1            Araku
# 4      Andhra Pradesh                           1            Araku
# ...               ...                         ...              ...
# 61720          Ladakh                           1           Ladakh
# 61721          Ladakh                           1           Ladakh
# 61722          Ladakh                           1           Ladakh
# 61723          Ladakh                           1           Ladakh
# 61724          Ladakh                           1           Ladakh
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1557153                      10    Palakonda
# 1                   1557153                      10    Palakonda
# 2                   1557153                      10    Palakonda
# 3                   1557153                      10    Palakonda
# 4                   1557153                      10    Palakonda
# ...                     ...                     ...          ...
# 61720                190576                       1          Leh
# 61721                190576                       1          Leh
# 61722                190576                       2       Kargil
# 61723                190576                       2       Kargil
# 61724                190576                       2       Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873
# 1       AVASHYA LAHARI . VARAM     BSP               1155
# 2            KOTHAPALLI GEETHA     BJP              66695
# 3           GUMMA THANUJA RANI   YSRCP              63302
# 4              CHANTI BADNAINA    JBNP               1977
# ...                        ...     ...                ...
# 61720          TSERING NAMGYAL     INC              32014
# 61721           MOHMAD HANEEFA     IND               5733
# 61722            TASHI GYALSON     BJP              10012
# 61723          TSERING NAMGYAL     INC               3756
# 61724           MOHMAD HANEEFA     IND              58710
#
# [61725 rows x 12 columns]

# %%
ad[(ad["ParliamentryName"] == "Nawada") & (ad["AssemblyName"] == "Hisua")]
# Out:
#      State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 7824         Bihar                          39           Nawada
# 7825         Bihar                          39           Nawada
# 7826         Bihar                          39           Nawada
# 7827         Bihar                          39           Nawada
# 7828         Bihar                          39           Nawada
# 7829         Bihar                          39           Nawada
# 7830         Bihar                          39           Nawada
# 7831         Bihar                          39           Nawada
#
#       Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 7824               2010286                     236        Hisua
# 7825               2010286                     236        Hisua
# 7826               2010286                     236        Hisua
# 7827               2010286                     236        Hisua
# 7828               2010286                     236        Hisua
# 7829               2010286                     236        Hisua
# 7830               2010286                     236        Hisua
# 7831               2010286                     236        Hisua
#
#       Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 7824                387202                    42549333                  2324
# 7825                387202                    42549333                  2324
# 7826                387202                    42549333                  2324
# 7827                387202                    42549333                  2324
# 7828                387202                    42549333                  2324
# 7829                387202                    42549333                  2324
# 7830                387202                    42549333                  2324
# 7831                387202                    42549333                  2324
#
#            Candidate Name   Party  Votes Secured Evm
# 7824         RANJIT KUMAR     BSP               3135
# 7825         VIVEK THAKUR     BJP              82966
# 7826        SHRAWAN KUMAR     RJD              63881
# 7827    ANAND KUMAR VERMA  BJNJGD               1411
# 7828       GANAURI PANDIT    PPID                782
# 7829  GAUTAM KUMAR BABLOO  BGDRPP               1140
# 7830         GUNJAN KUMAR     IND               5820
# 7831          BINOD YADAV     IND               8274

# %% [markdown]
# # Total vote percentage in Parliamentry constituencies Name

# %%
votes_sum = ad.groupby("ParliamentryName")[["Votes Secured Evm"]].sum()
nota = ad.groupby("ParliamentryName")[["Nota Votes Evm In AC"]].first()

total_df = votes_sum.merge(nota, on="ParliamentryName")

total_df["Total_Votes"] = total_df["Votes Secured Evm"] + total_df["Nota Votes Evm In AC"]

ad = ad.merge(total_df[["Total_Votes"]], left_on="ParliamentryName", right_index=True, how="left")
ad
# Out:
#         State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0      Andhra Pradesh                           1            Araku
# 1      Andhra Pradesh                           1            Araku
# 2      Andhra Pradesh                           1            Araku
# 3      Andhra Pradesh                           1            Araku
# 4      Andhra Pradesh                           1            Araku
# ...               ...                         ...              ...
# 61720          Ladakh                           1           Ladakh
# 61721          Ladakh                           1           Ladakh
# 61722          Ladakh                           1           Ladakh
# 61723          Ladakh                           1           Ladakh
# 61724          Ladakh                           1           Ladakh
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1557153                      10    Palakonda
# 1                   1557153                      10    Palakonda
# 2                   1557153                      10    Palakonda
# 3                   1557153                      10    Palakonda
# 4                   1557153                      10    Palakonda
# ...                     ...                     ...          ...
# 61720                190576                       1          Leh
# 61721                190576                       1          Leh
# 61722                190576                       2       Kargil
# 61723                190576                       2       Kargil
# 61724                190576                       2       Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm  Total_Votes
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873      1097249
# 1       AVASHYA LAHARI . VARAM     BSP               1155      1097249
# 2            KOTHAPALLI GEETHA     BJP              66695      1097249
# 3           GUMMA THANUJA RANI   YSRCP              63302      1097249
# 4              CHANTI BADNAINA    JBNP               1977      1097249
# ...                        ...     ...                ...          ...
# 61720          TSERING NAMGYAL     INC              32014       132056
# 61721           MOHMAD HANEEFA     IND               5733       132056
# 61722            TASHI GYALSON     BJP              10012       132056
# 61723          TSERING NAMGYAL     INC               3756       132056
# 61724           MOHMAD HANEEFA     IND              58710       132056
#
# [61725 rows x 13 columns]

# %%
ad.rename(columns = {"Total_Votes_y":"Total_votes"}, inplace =True)
ad
# Out:
#         State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0      Andhra Pradesh                           1            Araku
# 1      Andhra Pradesh                           1            Araku
# 2      Andhra Pradesh                           1            Araku
# 3      Andhra Pradesh                           1            Araku
# 4      Andhra Pradesh                           1            Araku
# ...               ...                         ...              ...
# 61720          Ladakh                           1           Ladakh
# 61721          Ladakh                           1           Ladakh
# 61722          Ladakh                           1           Ladakh
# 61723          Ladakh                           1           Ladakh
# 61724          Ladakh                           1           Ladakh
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1557153                      10    Palakonda
# 1                   1557153                      10    Palakonda
# 2                   1557153                      10    Palakonda
# 3                   1557153                      10    Palakonda
# 4                   1557153                      10    Palakonda
# ...                     ...                     ...          ...
# 61720                190576                       1          Leh
# 61721                190576                       1          Leh
# 61722                190576                       2       Kargil
# 61723                190576                       2       Kargil
# 61724                190576                       2       Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm  Total_Votes
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873      1097249
# 1       AVASHYA LAHARI . VARAM     BSP               1155      1097249
# 2            KOTHAPALLI GEETHA     BJP              66695      1097249
# 3           GUMMA THANUJA RANI   YSRCP              63302      1097249
# 4              CHANTI BADNAINA    JBNP               1977      1097249
# ...                        ...     ...                ...          ...
# 61720          TSERING NAMGYAL     INC              32014       132056
# 61721           MOHMAD HANEEFA     IND               5733       132056
# 61722            TASHI GYALSON     BJP              10012       132056
# 61723          TSERING NAMGYAL     INC               3756       132056
# 61724           MOHMAD HANEEFA     IND              58710       132056
#
# [61725 rows x 13 columns]

# %% [markdown]
# **Now we find turnout percentage in general constituencies:**
#
# **Turnout generalpercent in constituencies** = ( Total_votesTotal Electors in PC)*100
#
# **Total Votes** = the sum of all votes cast in a Parliamentary Constituency (including all candidates and NOTA).
#
# **Total Electors in PC** = the total number of registered voters in that constituency.
#
# This gives the overall voter turnout percentage for each constituency. It represents the proportion of eligible voters who actually participated in the election

# %%
ad["Turnout generalpercent"] = (ad["Total_Votes"]/ad["Total Electors In PC"])*100

# %%
ad
# Out:
#         State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0      Andhra Pradesh                           1            Araku
# 1      Andhra Pradesh                           1            Araku
# 2      Andhra Pradesh                           1            Araku
# 3      Andhra Pradesh                           1            Araku
# 4      Andhra Pradesh                           1            Araku
# ...               ...                         ...              ...
# 61720          Ladakh                           1           Ladakh
# 61721          Ladakh                           1           Ladakh
# 61722          Ladakh                           1           Ladakh
# 61723          Ladakh                           1           Ladakh
# 61724          Ladakh                           1           Ladakh
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1557153                      10    Palakonda
# 1                   1557153                      10    Palakonda
# 2                   1557153                      10    Palakonda
# 3                   1557153                      10    Palakonda
# 4                   1557153                      10    Palakonda
# ...                     ...                     ...          ...
# 61720                190576                       1          Leh
# 61721                190576                       1          Leh
# 61722                190576                       2       Kargil
# 61723                190576                       2       Kargil
# 61724                190576                       2       Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm  Total_Votes  \
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873      1097249
# 1       AVASHYA LAHARI . VARAM     BSP               1155      1097249
# 2            KOTHAPALLI GEETHA     BJP              66695      1097249
# 3           GUMMA THANUJA RANI   YSRCP              63302      1097249
# 4              CHANTI BADNAINA    JBNP               1977      1097249
# ...                        ...     ...                ...          ...
# 61720          TSERING NAMGYAL     INC              32014       132056
# 61721           MOHMAD HANEEFA     IND               5733       132056
# 61722            TASHI GYALSON     BJP              10012       132056
# 61723          TSERING NAMGYAL     INC               3756       132056
# 61724           MOHMAD HANEEFA     IND              58710       132056
#
#        Turnout generalpercent
# 0                   70.465073
# 1                   70.465073
# 2                   70.465073
# 3                   70.465073
# 4                   70.465073
# ...                       ...
# 61720               69.293090
# 61721               69.293090
# 61722               69.293090
# 61723               69.293090
# 61724               69.293090
#
# [61725 rows x 14 columns]

# %% [markdown]
# # Vote Percentage by each party or Party Performance Analysis

# %%
ad["Votesharepercentage"] = (ad["Votes Secured Evm"]/ad["Total_Votes"])*100
ad
# Out:
#         State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0      Andhra Pradesh                           1            Araku
# 1      Andhra Pradesh                           1            Araku
# 2      Andhra Pradesh                           1            Araku
# 3      Andhra Pradesh                           1            Araku
# 4      Andhra Pradesh                           1            Araku
# ...               ...                         ...              ...
# 61720          Ladakh                           1           Ladakh
# 61721          Ladakh                           1           Ladakh
# 61722          Ladakh                           1           Ladakh
# 61723          Ladakh                           1           Ladakh
# 61724          Ladakh                           1           Ladakh
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1557153                      10    Palakonda
# 1                   1557153                      10    Palakonda
# 2                   1557153                      10    Palakonda
# 3                   1557153                      10    Palakonda
# 4                   1557153                      10    Palakonda
# ...                     ...                     ...          ...
# 61720                190576                       1          Leh
# 61721                190576                       1          Leh
# 61722                190576                       2       Kargil
# 61723                190576                       2       Kargil
# 61724                190576                       2       Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm  Total_Votes  \
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873      1097249
# 1       AVASHYA LAHARI . VARAM     BSP               1155      1097249
# 2            KOTHAPALLI GEETHA     BJP              66695      1097249
# 3           GUMMA THANUJA RANI   YSRCP              63302      1097249
# 4              CHANTI BADNAINA    JBNP               1977      1097249
# ...                        ...     ...                ...          ...
# 61720          TSERING NAMGYAL     INC              32014       132056
# 61721           MOHMAD HANEEFA     IND               5733       132056
# 61722            TASHI GYALSON     BJP              10012       132056
# 61723          TSERING NAMGYAL     INC               3756       132056
# 61724           MOHMAD HANEEFA     IND              58710       132056
#
#        Turnout generalpercent  Votesharepercentage
# 0                   70.465073             0.352974
# 1                   70.465073             0.105263
# 2                   70.465073             6.078383
# 3                   70.465073             5.769155
# 4                   70.465073             0.180178
# ...                       ...                  ...
# 61720               69.293090            24.242746
# 61721               69.293090             4.341340
# 61722               69.293090             7.581632
# 61723               69.293090             2.844248
# 61724               69.293090            44.458412
#
# [61725 rows x 15 columns]

# %% [markdown]
# ## The column Votesharepercentage is calculated as:
#
# **Votesharepercentage** = (Votes Secured EVM / Total_Votes)*100
#
# **Votes Secured EVM**= the number of votes a candidate or party received through Electronic Voting Machines.
#
# **Total_Votes** = the total number of registered voters in that Parliamentary Constituency (PC).
#
# This gives the percentage of the total electorate that actually voted for a candidate/party, not just out of the people who cast their votes, but out of the entire eligible voting population.

# %% [markdown]
# # Total votes by party in that Parliamentry constituencies

# %%
ad["Votes_pc_party"] = ad.groupby(["ParliamentryName", "Party"])["Votes Secured Evm"].transform("sum")
ad
# Out:
#         State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0      Andhra Pradesh                           1            Araku
# 1      Andhra Pradesh                           1            Araku
# 2      Andhra Pradesh                           1            Araku
# 3      Andhra Pradesh                           1            Araku
# 4      Andhra Pradesh                           1            Araku
# ...               ...                         ...              ...
# 61720          Ladakh                           1           Ladakh
# 61721          Ladakh                           1           Ladakh
# 61722          Ladakh                           1           Ladakh
# 61723          Ladakh                           1           Ladakh
# 61724          Ladakh                           1           Ladakh
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1557153                      10    Palakonda
# 1                   1557153                      10    Palakonda
# 2                   1557153                      10    Palakonda
# 3                   1557153                      10    Palakonda
# 4                   1557153                      10    Palakonda
# ...                     ...                     ...          ...
# 61720                190576                       1          Leh
# 61721                190576                       1          Leh
# 61722                190576                       2       Kargil
# 61723                190576                       2       Kargil
# 61724                190576                       2       Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm  Total_Votes  \
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873      1097249
# 1       AVASHYA LAHARI . VARAM     BSP               1155      1097249
# 2            KOTHAPALLI GEETHA     BJP              66695      1097249
# 3           GUMMA THANUJA RANI   YSRCP              63302      1097249
# 4              CHANTI BADNAINA    JBNP               1977      1097249
# ...                        ...     ...                ...          ...
# 61720          TSERING NAMGYAL     INC              32014       132056
# 61721           MOHMAD HANEEFA     IND               5733       132056
# 61722            TASHI GYALSON     BJP              10012       132056
# 61723          TSERING NAMGYAL     INC               3756       132056
# 61724           MOHMAD HANEEFA     IND              58710       132056
#
#        Turnout generalpercent  Votesharepercentage  Votes_pc_party
# 0                   70.465073             0.352974          119016
# 1                   70.465073             0.105263           24858
# 2                   70.465073             6.078383          417113
# 3                   70.465073             5.769155          471470
# 4                   70.465073             0.180178            7205
# ...                       ...                  ...             ...
# 61720               69.293090            24.242746           35770
# 61721               69.293090             4.341340           64443
# 61722               69.293090             7.581632           31505
# 61723               69.293090             2.844248           35770
# 61724               69.293090            44.458412           64443
#
# [61725 rows x 16 columns]

# %% [markdown]
# ### NOTA votes per constituency

# %%
ad["NOTA_percent"] = (ad["Nota Votes Evm In AC"] / ad["Total_Votes"]) * 100

# %% [markdown]
# # Winning party in that Particular constiuencies

# %%
winner = ad.groupby("ParliamentryName")["Votes Secured Evm"].idxmax()
winner
winner = ad.loc[winner, ["ParliamentryName", "Party"]].rename(columns={"Party": "Winning Party"})

ad = ad.merge(winner, on="ParliamentryName", how="left")
ad
# Out:
#         State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0      Andhra Pradesh                           1            Araku
# 1      Andhra Pradesh                           1            Araku
# 2      Andhra Pradesh                           1            Araku
# 3      Andhra Pradesh                           1            Araku
# 4      Andhra Pradesh                           1            Araku
# ...               ...                         ...              ...
# 61720          Ladakh                           1           Ladakh
# 61721          Ladakh                           1           Ladakh
# 61722          Ladakh                           1           Ladakh
# 61723          Ladakh                           1           Ladakh
# 61724          Ladakh                           1           Ladakh
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1557153                      10    Palakonda
# 1                   1557153                      10    Palakonda
# 2                   1557153                      10    Palakonda
# 3                   1557153                      10    Palakonda
# 4                   1557153                      10    Palakonda
# ...                     ...                     ...          ...
# 61720                190576                       1          Leh
# 61721                190576                       1          Leh
# 61722                190576                       2       Kargil
# 61723                190576                       2       Kargil
# 61724                190576                       2       Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm  Total_Votes  \
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873      1097249
# 1       AVASHYA LAHARI . VARAM     BSP               1155      1097249
# 2            KOTHAPALLI GEETHA     BJP              66695      1097249
# 3           GUMMA THANUJA RANI   YSRCP              63302      1097249
# 4              CHANTI BADNAINA    JBNP               1977      1097249
# ...                        ...     ...                ...          ...
# 61720          TSERING NAMGYAL     INC              32014       132056
# 61721           MOHMAD HANEEFA     IND               5733       132056
# 61722            TASHI GYALSON     BJP              10012       132056
# 61723          TSERING NAMGYAL     INC               3756       132056
# 61724           MOHMAD HANEEFA     IND              58710       132056
#
#        Turnout generalpercent  Votesharepercentage  Votes_pc_party  \
# 0                   70.465073             0.352974          119016
# 1                   70.465073             0.105263           24858
# 2                   70.465073             6.078383          417113
# 3                   70.465073             5.769155          471470
# 4                   70.465073             0.180178            7205
# ...                       ...                  ...             ...
# 61720               69.293090            24.242746           35770
# 61721               69.293090             4.341340           64443
# 61722               69.293090             7.581632           31505
# 61723               69.293090             2.844248           35770
# 61724               69.293090            44.458412           64443
#
#        NOTA_percent Winning Party
# 0          0.404739         YSRCP
# 1          0.404739         YSRCP
# 2          0.404739         YSRCP
# 3          0.404739         YSRCP
# 4          0.404739         YSRCP
# ...             ...           ...
# 61720      0.255952           IND
# 61721      0.255952           IND
# 61722      0.422548           IND
# 61723      0.422548           IND
# 61724      0.422548           IND
#
# [61725 rows x 18 columns]

# %%
ad.dtypes
# Out:
# State/Ut Name                  object
# Parliamentryconstituencies      int64
# ParliamentryName               object
# Total Electors In PC            int64
# Assemblyconstituencies          int64
# AssemblyName                   object
# Total Electors In AC            int64
# Total Valid Votes In State      int64
# Nota Votes Evm In AC            int64
# Candidate Name                 object
# Party                          object
# Votes Secured Evm               int64
# Total_Votes                     int64
# Turnout generalpercent        float64
# Votesharepercentage           float64
# Votes_pc_party                  int64
# NOTA_percent                  float64
# Winning Party                  object
# dtype: object

# %% [markdown]
# ### Total seats won by party

# %%
ad= ad.sort_values(["ParliamentryName", "Votes Secured Evm"], ascending=[True, False])
winners_per_party = (
    ad.drop_duplicates(subset=["ParliamentryName"])["Winning Party"].value_counts()
)
print(winners_per_party)
# Out:
# Winning Party
# BJP           247
# INC            97
# SP             37
# AITC           28
# DMK            20
# TDP            16
# JD(U)          12
# SHS             8
# NCPSP           7
# SHSUBT          7
# IND             7
# LJPRV           5
# AAAP            3
# ADMK            3
# CPI(M)          3
# RJD             3
# CPI             3
# IUML            3
# YSRCP           3
# JMM             2
# CPI(ML)(L)      2
# JKN             2
# JnP             2
# JD(S)           2
# NCP             1
# SKM             1
# MDMK            1
# ASPKR           1
# RLTP            1
# ADAL            1
# VOTPP           1
# HAMS            1
# KEC             1
# RSP             1
# UPPL            1
# BJD             1
# AIMIM           1
# VCK             1
# SAD             1
# RLD             1
# BHRTADVSIP      1
# DMDK            1
# Name: count, dtype: int64

# %% [markdown]
# # Marginal Victory

# %% [markdown]
# ***Marginal victor*** = max(Votes Secured Evm) - 2ndmax(Votes Secured Evm)

# %%
df_sorted = ad.sort_values(["ParliamentryName", "Votes Secured Evm"], ascending=[True, False])
top2 = df_sorted.groupby("ParliamentryName").head()
margins = (
    top2.groupby("ParliamentryName")
        .apply(lambda x: x.iloc[0]["Votes Secured Evm"] - x.iloc[1]["Votes Secured Evm"])
        .reset_index(name="Margin")
)

ad = ad.merge(margins, on="ParliamentryName", how="left")
ad
# Out:
# C:\Users\amanp\AppData\Local\Temp\ipykernel_21588\2433604498.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.iloc[0]["Votes Secured Evm"] - x.iloc[1]["Votes Secured Evm"])
#       State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0         Rajasthan                          13            AJMER
# 1         Rajasthan                          13            AJMER
# 2         Rajasthan                          13            AJMER
# 3         Rajasthan                          13            AJMER
# 4         Rajasthan                          13            AJMER
# ...             ...                         ...              ...
# 61720     Telangana                           5        Zahirabad
# 61721     Telangana                           5        Zahirabad
# 61722     Telangana                           5        Zahirabad
# 61723     Telangana                           5        Zahirabad
# 61724     Telangana                           5        Zahirabad
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1999399                      98   KISHANGARH
# 1                   1999399                     105        KEKRI
# 2                   1999399                     104       MASUDA
# 3                   1999399                      99      PUSHKAR
# 4                   1999399                     102    NASIRABAD
# ...                     ...                     ...          ...
# 61720               1642425                      16    Kamareddy
# 61721               1642425                      35  Narayankhed
# 61722               1642425                      38   Zaheerabad
# 61723               1642425                      14     Banswada
# 61724               1642425                      14     Banswada
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    286257                    32885413                  1816
# 1                    264896                    32885413                  1742
# 2                    275740                    32885413                  1436
# 3                    254914                    32885413                  1496
# 4                    235530                    32885413                  1225
# ...                     ...                         ...                   ...
# 61720                255175                    21904129                   527
# 61721                237309                    21904129                   396
# 61722                275667                    21904129                   351
# 61723                197025                    21904129                   365
# 61724                197025                    21904129                   365
#
#              Candidate Name Party  Votes Secured Evm  Total_Votes  \
# 0       BHAGIRATH CHOUDHARY   BJP             107716      1180237
# 1       BHAGIRATH CHOUDHARY   BJP              98471      1180237
# 2       BHAGIRATH CHOUDHARY   BJP              97421      1180237
# 3       BHAGIRATH CHOUDHARY   BJP              95780      1180237
# 4       BHAGIRATH CHOUDHARY   BJP              89146      1180237
# ...                     ...   ...                ...          ...
# 61720  ROMALA BABU DURGAIAH  IPBP                 88      1222431
# 61721  ROMALA BABU DURGAIAH  IPBP                 80      1222431
# 61722  ROMALA BABU DURGAIAH  IPBP                 74      1222431
# 61723          ASHOK TALARI   IND                 73      1222431
# 61724  ROMALA BABU DURGAIAH  IPBP                 61      1222431
#
#        Turnout generalpercent  Votesharepercentage  Votes_pc_party  \
# 0                   59.029588             9.126642          741151
# 1                   59.029588             8.343324          741151
# 2                   59.029588             8.254359          741151
# 3                   59.029588             8.115319          741151
# 4                   59.029588             7.553229          741151
# ...                       ...                  ...             ...
# 61720               74.428421             0.007199             601
# 61721               74.428421             0.006544             601
# 61722               74.428421             0.006054             601
# 61723               74.428421             0.005972           30999
# 61724               74.428421             0.004990             601
#
#        NOTA_percent Winning Party  Margin
# 0          0.153867           BJP    9245
# 1          0.147597           BJP    9245
# 2          0.121670           BJP    9245
# 3          0.126754           BJP    9245
# 4          0.103793           BJP    9245
# ...             ...           ...     ...
# 61720      0.043111           INC   17519
# 61721      0.032394           INC   17519
# 61722      0.028713           INC   17519
# 61723      0.029859           INC   17519
# 61724      0.029859           INC   17519
#
# [61725 rows x 19 columns]

# %%
df_sorted = ad
df_sorted = df_sorted.drop_duplicates(subset=["ParliamentryName", "Candidate Name"])

top2 = df_sorted.groupby("ParliamentryName").head(2)
result = (
    top2.groupby("ParliamentryName")
        .apply(lambda x: pd.Series({
            "Winner": x.iloc[0]["Candidate Name"],
            "Winning Party": x.iloc[0]["Party"],
            "Winner Votes": x.iloc[0]["Votes Secured Evm"],
            "Runner-up": x.iloc[1]["Candidate Name"],
            "Runner-up Party": x.iloc[1]["Party"],
            "Runner-up Votes": x.iloc[1]["Votes Secured Evm"],
            "Margin": x.iloc[0]["Votes Secured Evm"] - x.iloc[1]["Votes Secured Evm"]
        }))
        .reset_index()
)
result
# Out:
# C:\Users\amanp\AppData\Local\Temp\ipykernel_21588\1758300775.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: pd.Series({
#      ParliamentryName                    Winner Winning Party  Winner Votes  \
# 0               AJMER       BHAGIRATH CHOUDHARY           BJP        107716
# 1               ALWAR           BHUPENDER YADAV           BJP        103363
# 2              AMBALA            VARUN CHAUDHRY           INC         98531
# 3    ANANTNAG-RAJOURI          MIAN ALTAF AHMAD           JKN         53751
# 4           ARAKKONAM         S JAGATHRATCHAKAN           DMK        105052
# ..                ...                       ...           ...           ...
# 535            Wardha       AMAR SHARADRAO KALE         NCPSP         95035
# 536           Wayanad              RAHUL GANDHI           INC        112310
# 537        West Delhi        KAMALJEET SEHRAWAT           BJP        153497
# 538  Yavatmal- Washim  SANJAY UTTAMRAO DESHMUKH        SHSUBT        113849
# 539         Zahirabad      SURESH KUMAR SHETKAR           INC        103129
#
#                              Runner-up Runner-up Party  Runner-up Votes  \
# 0                 RAMCHANDRA CHOUDHARY             INC            59047
# 1                          LALIT YADAV             INC            84895
# 2                        BANTO KATARIA             BJP            86523
# 3                       MEHBOOBA MUFTI           JKPDP            26483
# 4                            L VIJAYAN            ADMK            52551
# ..                                 ...             ...              ...
# 535           RAMDAS CHANDRABHAN TADAS             BJP            89968
# 536                         ANNIE RAJA             CPI            43626
# 537                     MAHABAL MISHRA            AAAP           109365
# 538  RAJSHRITAI HEMANT PATIL (MAHALLE)             SHS            97520
# 539                        B. B. PATIL             BJP            85610
#
#      Margin
# 0     48669
# 1     18468
# 2     12008
# 3     27268
# 4     52501
# ..      ...
# 535    5067
# 536   68684
# 537   44132
# 538   16329
# 539   17519
#
# [540 rows x 8 columns]

# %%
ad
# Out:
#       State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0         Rajasthan                          13            AJMER
# 1         Rajasthan                          13            AJMER
# 2         Rajasthan                          13            AJMER
# 3         Rajasthan                          13            AJMER
# 4         Rajasthan                          13            AJMER
# ...             ...                         ...              ...
# 61720     Telangana                           5        Zahirabad
# 61721     Telangana                           5        Zahirabad
# 61722     Telangana                           5        Zahirabad
# 61723     Telangana                           5        Zahirabad
# 61724     Telangana                           5        Zahirabad
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1999399                      98   KISHANGARH
# 1                   1999399                     105        KEKRI
# 2                   1999399                     104       MASUDA
# 3                   1999399                      99      PUSHKAR
# 4                   1999399                     102    NASIRABAD
# ...                     ...                     ...          ...
# 61720               1642425                      16    Kamareddy
# 61721               1642425                      35  Narayankhed
# 61722               1642425                      38   Zaheerabad
# 61723               1642425                      14     Banswada
# 61724               1642425                      14     Banswada
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    286257                    32885413                  1816
# 1                    264896                    32885413                  1742
# 2                    275740                    32885413                  1436
# 3                    254914                    32885413                  1496
# 4                    235530                    32885413                  1225
# ...                     ...                         ...                   ...
# 61720                255175                    21904129                   527
# 61721                237309                    21904129                   396
# 61722                275667                    21904129                   351
# 61723                197025                    21904129                   365
# 61724                197025                    21904129                   365
#
#              Candidate Name Party  Votes Secured Evm  Total_Votes  \
# 0       BHAGIRATH CHOUDHARY   BJP             107716      1180237
# 1       BHAGIRATH CHOUDHARY   BJP              98471      1180237
# 2       BHAGIRATH CHOUDHARY   BJP              97421      1180237
# 3       BHAGIRATH CHOUDHARY   BJP              95780      1180237
# 4       BHAGIRATH CHOUDHARY   BJP              89146      1180237
# ...                     ...   ...                ...          ...
# 61720  ROMALA BABU DURGAIAH  IPBP                 88      1222431
# 61721  ROMALA BABU DURGAIAH  IPBP                 80      1222431
# 61722  ROMALA BABU DURGAIAH  IPBP                 74      1222431
# 61723          ASHOK TALARI   IND                 73      1222431
# 61724  ROMALA BABU DURGAIAH  IPBP                 61      1222431
#
#        Turnout generalpercent  Votesharepercentage  Votes_pc_party  \
# 0                   59.029588             9.126642          741151
# 1                   59.029588             8.343324          741151
# 2                   59.029588             8.254359          741151
# 3                   59.029588             8.115319          741151
# 4                   59.029588             7.553229          741151
# ...                       ...                  ...             ...
# 61720               74.428421             0.007199             601
# 61721               74.428421             0.006544             601
# 61722               74.428421             0.006054             601
# 61723               74.428421             0.005972           30999
# 61724               74.428421             0.004990             601
#
#        NOTA_percent Winning Party  Margin
# 0          0.153867           BJP    9245
# 1          0.147597           BJP    9245
# 2          0.121670           BJP    9245
# 3          0.126754           BJP    9245
# 4          0.103793           BJP    9245
# ...             ...           ...     ...
# 61720      0.043111           INC   17519
# 61721      0.032394           INC   17519
# 61722      0.028713           INC   17519
# 61723      0.029859           INC   17519
# 61724      0.029859           INC   17519
#
# [61725 rows x 19 columns]

# %%
result[margin["ParliamentryName"]=="Araku"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 result[margin["ParliamentryName"]=="Araku"]
#
# NameError: name 'margin' is not defined

# %%
ad
# Out:
#       State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0         Rajasthan                          13            AJMER
# 1         Rajasthan                          13            AJMER
# 2         Rajasthan                          13            AJMER
# 3         Rajasthan                          13            AJMER
# 4         Rajasthan                          13            AJMER
# ...             ...                         ...              ...
# 61720     Telangana                           5        Zahirabad
# 61721     Telangana                           5        Zahirabad
# 61722     Telangana                           5        Zahirabad
# 61723     Telangana                           5        Zahirabad
# 61724     Telangana                           5        Zahirabad
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1999399                      98   KISHANGARH
# 1                   1999399                     105        KEKRI
# 2                   1999399                     104       MASUDA
# 3                   1999399                      99      PUSHKAR
# 4                   1999399                     102    NASIRABAD
# ...                     ...                     ...          ...
# 61720               1642425                      16    Kamareddy
# 61721               1642425                      35  Narayankhed
# 61722               1642425                      38   Zaheerabad
# 61723               1642425                      14     Banswada
# 61724               1642425                      14     Banswada
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    286257                    32885413                  1816
# 1                    264896                    32885413                  1742
# 2                    275740                    32885413                  1436
# 3                    254914                    32885413                  1496
# 4                    235530                    32885413                  1225
# ...                     ...                         ...                   ...
# 61720                255175                    21904129                   527
# 61721                237309                    21904129                   396
# 61722                275667                    21904129                   351
# 61723                197025                    21904129                   365
# 61724                197025                    21904129                   365
#
#              Candidate Name Party  Votes Secured Evm  Total_Votes  \
# 0       BHAGIRATH CHOUDHARY   BJP             107716      1180237
# 1       BHAGIRATH CHOUDHARY   BJP              98471      1180237
# 2       BHAGIRATH CHOUDHARY   BJP              97421      1180237
# 3       BHAGIRATH CHOUDHARY   BJP              95780      1180237
# 4       BHAGIRATH CHOUDHARY   BJP              89146      1180237
# ...                     ...   ...                ...          ...
# 61720  ROMALA BABU DURGAIAH  IPBP                 88      1222431
# 61721  ROMALA BABU DURGAIAH  IPBP                 80      1222431
# 61722  ROMALA BABU DURGAIAH  IPBP                 74      1222431
# 61723          ASHOK TALARI   IND                 73      1222431
# 61724  ROMALA BABU DURGAIAH  IPBP                 61      1222431
#
#        Turnout generalpercent  Votesharepercentage  Votes_pc_party  \
# 0                   59.029588             9.126642          741151
# 1                   59.029588             8.343324          741151
# 2                   59.029588             8.254359          741151
# 3                   59.029588             8.115319          741151
# 4                   59.029588             7.553229          741151
# ...                       ...                  ...             ...
# 61720               74.428421             0.007199             601
# 61721               74.428421             0.006544             601
# 61722               74.428421             0.006054             601
# 61723               74.428421             0.005972           30999
# 61724               74.428421             0.004990             601
#
#        NOTA_percent Winning Party  Margin
# 0          0.153867           BJP    9245
# 1          0.147597           BJP    9245
# 2          0.121670           BJP    9245
# 3          0.126754           BJP    9245
# 4          0.103793           BJP    9245
# ...             ...           ...     ...
# 61720      0.043111           INC   17519
# 61721      0.032394           INC   17519
# 61722      0.028713           INC   17519
# 61723      0.029859           INC   17519
# 61724      0.029859           INC   17519
#
# [61725 rows x 19 columns]

# %%
pd.read_sql_query("select * from elections",conn)
# Out:
#         State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0      Andhra Pradesh                           1            Araku
# 1      Andhra Pradesh                           1            Araku
# 2      Andhra Pradesh                           1            Araku
# 3      Andhra Pradesh                           1            Araku
# 4      Andhra Pradesh                           1            Araku
# ...               ...                         ...              ...
# 61720          Ladakh                           1           Ladakh
# 61721          Ladakh                           1           Ladakh
# 61722          Ladakh                           1           Ladakh
# 61723          Ladakh                           1           Ladakh
# 61724          Ladakh                           1           Ladakh
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1557153                      10    Palakonda
# 1                   1557153                      10    Palakonda
# 2                   1557153                      10    Palakonda
# 3                   1557153                      10    Palakonda
# 4                   1557153                      10    Palakonda
# ...                     ...                     ...          ...
# 61720                190576                       1          Leh
# 61721                190576                       1          Leh
# 61722                190576                       2       Kargil
# 61723                190576                       2       Kargil
# 61724                190576                       2       Kargil
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    195673                    33327256                  4441
# 1                    195673                    33327256                  4441
# 2                    195673                    33327256                  4441
# 3                    195673                    33327256                  4441
# 4                    195673                    33327256                  4441
# ...                     ...                         ...                   ...
# 61720                 92700                      134612                   338
# 61721                 92700                      134612                   338
# 61722                 97876                      134612                   558
# 61723                 97876                      134612                   558
# 61724                 97876                      134612                   558
#
#                 Candidate Name   Party  Votes Secured Evm
# 0      APPALANARASA PACHIPENTA  CPI(M)               3873
# 1       AVASHYA LAHARI . VARAM     BSP               1155
# 2            KOTHAPALLI GEETHA     BJP              66695
# 3           GUMMA THANUJA RANI   YSRCP              63302
# 4              CHANTI BADNAINA    JBNP               1977
# ...                        ...     ...                ...
# 61720          TSERING NAMGYAL     INC              32014
# 61721           MOHMAD HANEEFA     IND               5733
# 61722            TASHI GYALSON     BJP              10012
# 61723          TSERING NAMGYAL     INC               3756
# 61724           MOHMAD HANEEFA     IND              58710
#
# [61725 rows x 12 columns]

# %%
cursor = conn.cursor()

# %%
ad.dtypes
# Out:
# State/Ut Name                  object
# Parliamentryconstituencies      int64
# ParliamentryName               object
# Total Electors In PC            int64
# Assemblyconstituencies          int64
# AssemblyName                   object
# Total Electors In AC            int64
# Total Valid Votes In State      int64
# Nota Votes Evm In AC            int64
# Candidate Name                 object
# Party                          object
# Votes Secured Evm               int64
# Total_Votes                     int64
# Turnout generalpercent        float64
# Votesharepercentage           float64
# Votes_pc_party                  int64
# NOTA_percent                  float64
# Winning Party                  object
# Margin                          int64
# dtype: object

# %%
cursor.execute("""
    CREATE TABLE final_results (
        "State/Ut Name" VARCHAR(100),
        "Parliamentryconstituencies" INT,
        "ParliamentryName" VARCHAR(100),
        "Total Electors In PC" INT,
        "Assemblyconstituencies" INT,
        "AssemblyName" VARCHAR(100),
        "Total Electors In AC" INT,
        "Total Valid Votes In State" INT,
        "Nota Votes Evm In AC" INT,
        "Candidate Name" VARCHAR(100),
        "Party" VARCHAR(100),
        "Votes Secured Evm" INT,
        "Total_Votes" INT,
        "Turnout generalpercent" DECIMAL(15,2),
        "Votesharepercentage" DECIMAL(15,2),
        "Votes_pc_party" INT,
        "Winning Party" VARCHAR(100),
        "Margin" INT
    );
""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 cursor.execute("""
#       2     CREATE TABLE final_results (
#       3         "State/Ut Name" VARCHAR(100),
#       4         "Parliamentryconstituencies" INT,
#       5         "ParliamentryName" VARCHAR(100),
#       6         "Total Electors In PC" INT,
#       7         "Assemblyconstituencies" INT,
#       8         "AssemblyName" VARCHAR(100),
#       9         "Total Electors In AC" INT,
#      10         "Total Valid Votes In State" INT,
#      11         "Nota Votes Evm In AC" INT,
#      12         "Candidate Name" VARCHAR(100),
#      13         "Party" VARCHAR(100),
#      14         "Votes Secured Evm" INT,
#      15         "Total_Votes" INT,
#      16         "Turnout generalpercent" DECIMAL(15,2),
#      17         "Votesharepercentage" DECIMAL(15,2),
#      18         "Votes_pc_party" INT,
#      19         "Winning Party" VARCHAR(100),
#      20         "Margin" INT
#      21     );
#      22 """)
#
# OperationalError: table final_results already exists

# %%
final_results = ad.to_sql("final_results", conn, if_exists="replace", index=False)

# %%
final_results
# Out:
# 61725

# %%
conn

# %%
pd.read_sql_query("select * from final_results",conn)
# Out:
#       State/Ut Name  Parliamentryconstituencies ParliamentryName  \
# 0         Rajasthan                          13            AJMER
# 1         Rajasthan                          13            AJMER
# 2         Rajasthan                          13            AJMER
# 3         Rajasthan                          13            AJMER
# 4         Rajasthan                          13            AJMER
# ...             ...                         ...              ...
# 61720     Telangana                           5        Zahirabad
# 61721     Telangana                           5        Zahirabad
# 61722     Telangana                           5        Zahirabad
# 61723     Telangana                           5        Zahirabad
# 61724     Telangana                           5        Zahirabad
#
#        Total Electors In PC  Assemblyconstituencies AssemblyName  \
# 0                   1999399                      98   KISHANGARH
# 1                   1999399                     105        KEKRI
# 2                   1999399                     104       MASUDA
# 3                   1999399                      99      PUSHKAR
# 4                   1999399                     102    NASIRABAD
# ...                     ...                     ...          ...
# 61720               1642425                      16    Kamareddy
# 61721               1642425                      35  Narayankhed
# 61722               1642425                      38   Zaheerabad
# 61723               1642425                      14     Banswada
# 61724               1642425                      14     Banswada
#
#        Total Electors In AC  Total Valid Votes In State  Nota Votes Evm In AC  \
# 0                    286257                    32885413                  1816
# 1                    264896                    32885413                  1742
# 2                    275740                    32885413                  1436
# 3                    254914                    32885413                  1496
# 4                    235530                    32885413                  1225
# ...                     ...                         ...                   ...
# 61720                255175                    21904129                   527
# 61721                237309                    21904129                   396
# 61722                275667                    21904129                   351
# 61723                197025                    21904129                   365
# 61724                197025                    21904129                   365
#
#              Candidate Name Party  Votes Secured Evm  Total_Votes  \
# 0       BHAGIRATH CHOUDHARY   BJP             107716      1180237
# 1       BHAGIRATH CHOUDHARY   BJP              98471      1180237
# 2       BHAGIRATH CHOUDHARY   BJP              97421      1180237
# 3       BHAGIRATH CHOUDHARY   BJP              95780      1180237
# 4       BHAGIRATH CHOUDHARY   BJP              89146      1180237
# ...                     ...   ...                ...          ...
# 61720  ROMALA BABU DURGAIAH  IPBP                 88      1222431
# 61721  ROMALA BABU DURGAIAH  IPBP                 80      1222431
# 61722  ROMALA BABU DURGAIAH  IPBP                 74      1222431
# 61723          ASHOK TALARI   IND                 73      1222431
# 61724  ROMALA BABU DURGAIAH  IPBP                 61      1222431
#
#        Turnout generalpercent  Votesharepercentage  Votes_pc_party  \
# 0                   59.029588             9.126642          741151
# 1                   59.029588             8.343324          741151
# 2                   59.029588             8.254359          741151
# 3                   59.029588             8.115319          741151
# 4                   59.029588             7.553229          741151
# ...                       ...                  ...             ...
# 61720               74.428421             0.007199             601
# 61721               74.428421             0.006544             601
# 61722               74.428421             0.006054             601
# 61723               74.428421             0.005972           30999
# 61724               74.428421             0.004990             601
#
#        NOTA_percent Winning Party  Margin
# 0          0.153867           BJP    9245
# 1          0.147597           BJP    9245
# 2          0.121670           BJP    9245
# 3          0.126754           BJP    9245
# 4          0.103793           BJP    9245
# ...             ...           ...     ...
# 61720      0.043111           INC   17519
# 61721      0.032394           INC   17519
# 61722      0.028713           INC   17519
# 61723      0.029859           INC   17519
# 61724      0.029859           INC   17519
#
# [61725 rows x 19 columns]
